# %% [markdown]
# # Libraries Used

# %%
import numpy as np
import scipy 
import scipy.misc
from keras.models import *
from keras.layers import Input, merge, Conv1D,Conv2D, MaxPooling2D, UpSampling2D, Dropout, Cropping2D
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as keras
from keras.models import load_model
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading the Model

# %%
model = load_model('aerial_model.h5')
# Out:
# C:\Users\Me\Anaconda3\lib\site-packages\keras\engine\topology.py:1269: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   return cls(**config)

# %% [markdown]
# # Plotting the Segmentation

# %%
def op(X_test,X_test_color,Y_test):
    plt.figure(figsize=(12,8))
    
    
    plt.subplot(1, 3, 1)

    a = Y_test.copy()
    c = a.flatten().reshape(512,512).T
    plt.imshow(c, cmap='Greys');
    #plt.colorbar()

    plt.subplot(1, 3, 2)

    c_bar = X_test.reshape(512,512).T
    plt.imshow(c_bar, cmap='Greys');
    #plt.colorbar()

    plt.subplot(1, 3, 3)

    d_bar = X_test_color.T
    plt.imshow(d_bar);
    #plt.colorbar()

    plt.show()

# %% [markdown]
# # Zip Code 19034 - 1

# %%
X_test = np.expand_dims(scipy.misc.imread('C:\\Users\\Me\\Documents\\UPENN_COURSEWORK\\Big_Data_Analytics_CIS545\\Project\\FINAL_CODE\\Final_Test_Images\\19034_1.tif').T,axis=0)

X_test_color = (scipy.misc.imread('C:\\Users\\Me\\Documents\\UPENN_COURSEWORK\\Big_Data_Analytics_CIS545\\Project\\FINAL_CODE\\Final_Test_Images\\c_19034_1.tif').T)

print(X_test.shape)
X_test = X_test.reshape(*X_test.shape,1)
X_test = X_test.astype('float32')
X_test/= 255


Y_test = model.predict(X_test, verbose=1)

Y_test[Y_test > 0.3] = 1
Y_test[Y_test <= 0.3] = 0

op(X_test,X_test_color,Y_test)
# Out:
# (1, 512, 512)
# 1/1 [==============================] - 19s 19s/step

# %% [markdown]
# # Zip Code 19034 - 2

# %%
X_test = np.expand_dims(scipy.misc.imread('C:\\Users\\Me\\Documents\\UPENN_COURSEWORK\\Big_Data_Analytics_CIS545\\Project\\FINAL_CODE\\Final_Test_Images\\19034_2.tif').T,axis=0)

X_test_color = (scipy.misc.imread('C:\\Users\\Me\\Documents\\UPENN_COURSEWORK\\Big_Data_Analytics_CIS545\\Project\\FINAL_CODE\\Final_Test_Images\\c_19034_2.tif').T)


print(X_test.shape)
X_test = X_test.reshape(*X_test.shape,1)
X_test = X_test.astype('float32')
X_test/= 255


Y_test = model.predict(X_test, verbose=1)

Y_test[Y_test > 0.3] = 1
Y_test[Y_test <= 0.3] = 0

op(X_test,X_test_color,Y_test)
# Out:
# (1, 512, 512)
# 1/1 [==============================] - 21s 21s/step

# %% [markdown]
# # Zip Code 19121 - 1

# %%
X_test = np.expand_dims(scipy.misc.imread('C:\\Users\\Me\\Documents\\UPENN_COURSEWORK\\Big_Data_Analytics_CIS545\\Project\\FINAL_CODE\\Final_Test_Images\\19121_1.tif').T,axis=0)

X_test_color = (scipy.misc.imread('C:\\Users\\Me\\Documents\\UPENN_COURSEWORK\\Big_Data_Analytics_CIS545\\Project\\FINAL_CODE\\Final_Test_Images\\c_19121_1.tif').T)


print(X_test.shape)
X_test = X_test.reshape(*X_test.shape,1)
X_test = X_test.astype('float32')
X_test/= 255


Y_test = model.predict(X_test, verbose=1)

Y_test[Y_test > 0.3] = 1
Y_test[Y_test <= 0.3] = 0

op(X_test,X_test_color,Y_test)
# Out:
# (1, 512, 512)
# 1/1 [==============================] - 22s 22s/step

# %% [markdown]
# # Zip Code 19121 - 2

# %%
X_test = np.expand_dims(scipy.misc.imread('C:\\Users\\Me\\Documents\\UPENN_COURSEWORK\\Big_Data_Analytics_CIS545\\Project\\FINAL_CODE\\Final_Test_Images\\19121_2.tif').T,axis=0)

X_test_color = (scipy.misc.imread('C:\\Users\\Me\\Documents\\UPENN_COURSEWORK\\Big_Data_Analytics_CIS545\\Project\\FINAL_CODE\\Final_Test_Images\\c_19121_2.tif').T)


print(X_test.shape)
X_test = X_test.reshape(*X_test.shape,1)
X_test = X_test.astype('float32')
X_test/= 255


Y_test = model.predict(X_test, verbose=1)

Y_test[Y_test > 0.3] = 1
Y_test[Y_test <= 0.3] = 0

op(X_test,X_test_color,Y_test)
# Out:
# (1, 512, 512)
# 1/1 [==============================] - 22s 22s/step

# %% [markdown]
# # Zip Code 19121 - 3

# %%
X_test = np.expand_dims(scipy.misc.imread('C:\\Users\\Me\\Documents\\UPENN_COURSEWORK\\Big_Data_Analytics_CIS545\\Project\\FINAL_CODE\\Final_Test_Images\\19121_3.tif').T,axis=0)

X_test_color = (scipy.misc.imread('C:\\Users\\Me\\Documents\\UPENN_COURSEWORK\\Big_Data_Analytics_CIS545\\Project\\FINAL_CODE\\Final_Test_Images\\c_19121_3.tif').T)


print(X_test.shape)
X_test = X_test.reshape(*X_test.shape,1)
X_test = X_test.astype('float32')
X_test/= 255


Y_test = model.predict(X_test, verbose=1)

Y_test[Y_test > 0.3] = 1
Y_test[Y_test <= 0.3] = 0

op(X_test,X_test_color,Y_test)
# Out:
# (1, 512, 512)
# 1/1 [==============================] - 19s 19s/step

# %% [markdown]
# # Zip Code 19144 - 1

# %%
X_test = np.expand_dims(scipy.misc.imread('C:\\Users\\Me\\Documents\\UPENN_COURSEWORK\\Big_Data_Analytics_CIS545\\Project\\FINAL_CODE\\Final_Test_Images\\19144_1.tif').T,axis=0)

X_test_color = (scipy.misc.imread('C:\\Users\\Me\\Documents\\UPENN_COURSEWORK\\Big_Data_Analytics_CIS545\\Project\\FINAL_CODE\\Final_Test_Images\\c_19144_1.tif').T)


print(X_test.shape)
X_test = X_test.reshape(*X_test.shape,1)
X_test = X_test.astype('float32')
X_test/= 255


Y_test = model.predict(X_test, verbose=1)

Y_test[Y_test > 0.3] = 1
Y_test[Y_test <= 0.3] = 0

op(X_test,X_test_color,Y_test)
# Out:
# (1, 512, 512)
# 1/1 [==============================] - 19s 19s/step

# %% [markdown]
# # Zip Code 19144 - 2

# %%
X_test = np.expand_dims(scipy.misc.imread('C:\\Users\\Me\\Documents\\UPENN_COURSEWORK\\Big_Data_Analytics_CIS545\\Project\\FINAL_CODE\\Final_Test_Images\\19144_2.tif').T,axis=0)

X_test_color = (scipy.misc.imread('C:\\Users\\Me\\Documents\\UPENN_COURSEWORK\\Big_Data_Analytics_CIS545\\Project\\FINAL_CODE\\Final_Test_Images\\c_19144_2.tif').T)


print(X_test.shape)
X_test = X_test.reshape(*X_test.shape,1)
X_test = X_test.astype('float32')
X_test/= 255


Y_test = model.predict(X_test, verbose=1)

Y_test[Y_test > 0.3] = 1
Y_test[Y_test <= 0.3] = 0

op(X_test,X_test_color,Y_test)
# Out:
# (1, 512, 512)
# 1/1 [==============================] - 24s 24s/step
